# %% [markdown]
# __Creates the next 6 videos from the original:__
#     - 6x rotation and resize
#     - 2x shear
#     - original
#
# __There are more options if required__

# %%
import vidaug.augmentors as va
import cv2
import numpy as np
import os
import sys
print(cv2.__version__)
# Out:
# 4.2.0

# %%
def video_loader(path, modality="RGB"):  
    vidcap = cv2.VideoCapture(path)
    success,image = vidcap.read()
    count = 0
    frames = []
    while success:
        #cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file
        success,image = vidcap.read()
        frames.append(image)
        #print ('Read a new frame: ', success)
        count = count + 1
    return frames

# %%
#Move the original video to the new folder
def original_video(inputpath, outputpath):
    frames = video_loader(inputpath)
    pathout = outputpath+'original.mp4'
    if(os.path.exists(pathout)==False):
        height, width, layers = frames[0].shape
        size = (width, height)
        out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
        for img in frames:
            out.write(img)
        out.release()
        #print('original finished')

# %%
#Resize videos into the new folder
def new_video_resized(inputpath, outputpath):
    frames = video_loader(inputpath)
    for i in range(3):
        c = 0
        pathout = outputpath+'resize'+str(i+1)+'.mp4'
        if(os.path.exists(pathout)==False):
            #print(pathout)
            sometimes = lambda aug: va.Sometimes(1, aug) # Used to apply augmentor with 100% probability
            seq = va.Sequential([va.RandomResize(0.4)])
            videoaug = seq(frames[:-1])
            height, width, layers = videoaug[0].shape
            size = (width, height)
            #print(size)
            out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
            #print(videoaug[0].shape)
            for img in videoaug:
                #print(img.size)
                out.write(img)
            out.release()
            c = 1
    if c == 1:
        print('resize ...done')
        #print('resized '+str(i+1)+' finished')

# %%
#Rotate videos into the new folder
def new_video_angle(inputpath, outputpath):
    frames = video_loader(inputpath)
    for i in range(2):
        c = 0
        pathout = outputpath+'rotate'+str(i+1)+'.mp4'
        if(os.path.exists(pathout)==False):
            #print(pathout)
            sometimes = lambda aug: va.Sometimes(1, aug) # Used to apply augmentor with 100% probability
            seq = va.Sequential([va.RandomRotate(20)])
            videoaug = seq(frames[:-1])
            height, width, layers = videoaug[0].shape
            size = (width, height)
            #print(size)
            out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
            #print(videoaug[0].shape)
            for img in videoaug:
                #print(img.size)
                out.write(img)
            out.release()
            c = 1
            #print('rotated '+str(i+1)+' finished')
    if c == 1:
        print('rotation ...done')

# %%
#Mirror videos horizontaly
def new_video_hmirror(inputpath, outputpath):
    frames = video_loader(inputpath)
    pathout = outputpath+'hflip.mp4'
    if(os.path.exists(pathout)==False):
        #print(pathout)
        sometimes = lambda aug: va.Sometimes(1, aug) # Used to apply augmentor with 100% probability
        #print('h')
        seq = va.Sequential([va.HorizontalFlip()])
        videoaug = seq(frames[:-1])
        height, width, layers = videoaug[0].shape
        size = (width, height)
        #print(size)
        out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
        #print(videoaug[0].shape)
        for img in videoaug:
            #print(img.size)
            out.write(img)
        out.release()
        print('flip ...done')
        #print('rotated '+str(i+1)+' finished')

# %%
#Shear videos into the new folder
def new_video_shear(inputpath, outputpath):
    frames = video_loader(inputpath)
    for i in range(2):
        c = 0
        pathout = outputpath+'shear'+str(i+1)+'.mp4'
        if(os.path.exists(pathout)==False):
            #print(pathout)
            sometimes = lambda aug: va.Sometimes(1, aug) # Used to apply augmentor with 100% probability
            seq = va.Sequential([va.RandomShear(0.2, 0.2)])
            videoaug = seq(frames[:-1])
            height, width, layers = videoaug[0].shape
            size = (width, height)
            #print(size)
            out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
            #print(videoaug[0].shape)
            for img in videoaug:
                #print(img.size)
                out.write(img)
            out.release()
            c = 1
            #print('rotated '+str(i+1)+' finished')
    if c == 1:
        print('shear ...done')

# %%
#Resize and Rotate videos into the new folder
def new_video_resized_rotated(inputpath, outputpath):
    frames = video_loader(inputpath)
    for i in range(6):
        c = 0
        pathout = outputpath+'resize'+str(i+1)+'.mp4'
        if(os.path.exists(pathout)==False):
            #print(pathout)
            sometimes = lambda aug: va.Sometimes(1, aug) # Used to apply augmentor with 100% probability
            seq = va.Sequential([va.RandomResize(0.4)])
            seq2 = va.Sequential([va.RandomRotate(15)])
            videoaug1 = seq(frames[:-1])
            videoaug = seq2(videoaug1)
            height, width, layers = videoaug[0].shape
            size = (width, height)
            #print(size)
            out = cv2.VideoWriter(pathout, cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
            #print(videoaug[0].shape)
            for img in videoaug:
                #print(img.size)
                out.write(img)
            out.release()
            c = 1
    if c == 1:
        print('resize ...done')
        #print('resized '+str(i+1)+' finished')

# %%
inputpath = '/home/andope16/Videos/newSign/original/'
outputpath = '/home/andope16/Videos/newSign/augmented/'
folderlist = os.listdir(inputpath)

count = 0
for folder in folderlist:
    if not(os.path.isdir(outputpath+folder)):
        os.mkdir(outputpath+folder)
    newfolder = folder+'/'
    videolist = os.listdir(inputpath+newfolder)
    
    for video in videolist:
        try:
            count = count+1
            print(str(count)+' '+video+': ...start')

            inputvideopath = inputpath+newfolder+video
            outputvideopath = outputpath+newfolder+video[:-4]

            #new_video_hmirror(inputvideopath, outputvideopath)
            #print(outputvideopath)
            new_video_resized_rotated(inputvideopath, outputvideopath)
            #print(outputvideopath)
            #new_video_angle(inputvideopath, outputvideopath)
            #print(outputvideopath)
            new_video_shear(inputvideopath, outputvideopath)

            original_video(inputvideopath, outputvideopath)
            print('...Completed')
            print()
        except:
            pass
print()
print('END')
print()

min_frames()
# Out:
# 1 understandADL3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 2 understandPB2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 3 understandFr5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 4 understandML50.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 5 understandPB3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 6 understandFr1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 7 understandFr3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 8 understandADL2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 9 understandML51.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 10 understandADL5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 11 understandPB4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 12 understandADL4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 13 understandPB1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 14 understandFr4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 15 understandML52.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 16 understandML53.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 17 understandADL1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 18 understandFr2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 19 helloML50.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 20 helloFr3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 21 helloML54.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 22 helloFr5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 23 helloADL1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 24 helloFr1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 25 helloADL4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 26 helloML53.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 27 helloPB1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 28 helloPB2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 29 helloPB4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 30 helloFr2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 31 helloFr4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 32 helloADL6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 33 helloADL2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 34 helloPB3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 35 helloML51.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 36 helloML52.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 37 helloADL5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 38 helloPB5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 39 signANG29.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 40 signML6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 41 signANG21.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 42 signANG18.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 43 signANG3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 44 signML2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 45 signML9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 46 SignSAF34.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 47 SignSAF42.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 48 signADL21.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 49 signFr1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 50 SignSAF3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 51 signFr7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 52 signEAF2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 53 SignSAF33.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 54 signPB8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 55 signEAF8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 56 signEAF6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 57 signPB10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 58 SignSAF11.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 59 signML8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 60 signEAF19.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 61 signANG8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 62 signPB1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 63 SignSAF30.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 64 signANG13.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 65 signEAF4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 66 signML5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 67 signANG14.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 68 signEAF30.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 69 signANG34.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 70 signADL10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 71 signEAF5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 72 signADL3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 73 signADL5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 74 signANG28.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 75 signADL24.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 76 signEAF22.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 77 SignSAF45.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 78 signANG16.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 79 signEAF27.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 80 signADL6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 81 signADL14.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 82 SignSAF40.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 83 SignSAF36.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 84 SignSAF31.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 85 signANG33.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 86 signEAF13.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 87 signFr5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 88 signEAF14.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 89 signADL13.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 90 signEAF28.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 91 signANG27.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 92 signANG31.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 93 signFr3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 94 signANG10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 95 signFr8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 96 signFr4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 97 signANG24.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 98 signADL15.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 99 signFr6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 100 signANG38.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 101 signPB5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 102 signANG19.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 103 SignSAF2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 104 SignSAF41.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 105 signPB6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 106 signANG9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 107 signEAF26.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 108 signADL18.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 109 SignSAF25.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 110 signPB7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 111 signANG36.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 112 signADL11.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 113 signPB4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 114 signANG23.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 115 signANG32.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 116 SignSAF7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 117 SignSAF29.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 118 signADL22.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 119 signEAF24.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 120 SignSAF46.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 121 signANG35.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 122 signANG20.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 123 SignSAF28.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 124 signADL9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 125 signADL1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 126 signPB12.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 127 SignSAF1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 128 SignSAF13.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 129 signFr9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 130 signEAF21.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 131 SignSAF35.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 132 SignSAF39.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 133 SignSAF9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 134 signADL4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 135 signANG6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 136 SignSAF19.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 137 signEAF12.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 138 signANG11.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 139 SignSAF24.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 140 signEAF10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 141 signPB11.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 142 signML1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 143 signANG26.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 144 signPB2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 145 signEAF17.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 146 signADL2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 147 signEAF31.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 148 signANG4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 149 SignSAF21.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 150 signADL8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 151 signADL16.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 152 SignSAF27.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 153 SignSAF8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 154 signEAF20.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 155 SignSAF4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 156 signFr2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 157 signANG7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 158 signEAF3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 159 signML4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 160 signEAF23.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 161 SignSAF44.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 162 SignSAF22.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 163 SignSAF37.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 164 signADL23.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 165 SignSAF32.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 166 signEAF18.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 167 signANG17.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 168 signEAF25.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 169 SignSAF17.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 170 SignSAF10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 171 SignSAF5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 172 SignSAF18.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 173 SignSAF15.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 174 SignSAF43.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 175 SignSAF23.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 176 SignSAF16.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 177 signEAF9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 178 signADL19.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 179 signANG22.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 180 signEAF1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 181 signEAF15.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 182 signANG5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 183 signANG2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 184 signANG25.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 185 SignSAF12.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 186 signEAF7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 187 signEAF29.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 188 signADL7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 189 signEAF11.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 190 SignSAF14.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 191 signANG15.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 192 signADL17.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 193 signANG30.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 194 signPB9.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 195 signML10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 196 signADL20.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 197 signML3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 198 signADL12.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 199 signFr10.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 200 signANG39.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 201 SignSAF26.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 202 signANG12.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 203 SignSAF38.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 204 signML7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 205 signANG37.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 206 SignSAF20.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 207 signPB3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 208 signEAF16.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 209 SignSAF6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 210 noADL2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 211 noADL7.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 212 noPB1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 213 noFr1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 214 noADL3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 215 noADL1.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 216 noML50.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 217 noFr2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 218 noML53.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 219 noFr3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 220 noML54.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 221 noML52.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 222 noADL8.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 223 noADL4.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 224 noADL5.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 225 noML51.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 226 noPB2.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 227 noADL6.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
# 228 noPB3.mp4: ...start
# resize ...done
# shear ...done
# ...Completed
#
#
# END
#
# video frames:
# start...
# calculating min number of frames...
#
# understand:
# understandADL3.mp4: 47
# understandPB2.mp4: 75
# understandFr5.mp4: 55
# understandML50.mp4: 67
# understandPB3.mp4: 55
# understandFr1.mp4: 81
# understandFr3.mp4: 48
# understandADL2.mp4: 43
# understandML51.mp4: 76
# understandADL5.mp4: 52
# understandPB4.mp4: 67
# understandADL4.mp4: 46
# understandPB1.mp4: 52
# understandFr4.mp4: 74
# understandML52.mp4: 92
# understandML53.mp4: 75
# understandADL1.mp4: 50
# understandFr2.mp4: 71
#
# hello:
# helloML50.mp4: 53
# helloFr3.mp4: 73
# helloML54.mp4: 46
# helloFr5.mp4: 49
# helloADL1.mp4: 38
# helloFr1.mp4: 61
# helloADL4.mp4: 48
# helloML53.mp4: 61
# helloPB1.mp4: 48
# helloPB2.mp4: 57
# helloPB4.mp4: 49
# helloFr2.mp4: 38
# helloFr4.mp4: 43
# helloADL6.mp4: 49
# helloADL2.mp4: 59
# helloPB3.mp4: 49
# helloML51.mp4: 52
# helloML52.mp4: 43
# helloADL5.mp4: 56
# helloPB5.mp4: 60
#
# sign:
# signANG29.mp4: 30
# signML6.mp4: 81
# signANG21.mp4: 33
# signANG18.mp4: 46
# signANG3.mp4: 44
# signML2.mp4: 55
# signML9.mp4: 93
# SignSAF34.mp4: 48
# SignSAF42.mp4: 51
# signADL21.mp4: 65
# signFr1.mp4: 65
# SignSAF3.mp4: 54
# signFr7.mp4: 89
# signEAF2.mp4: 42
# SignSAF33.mp4: 50
# signPB8.mp4: 90
# signEAF8.mp4: 28
# signEAF6.mp4: 33
# signPB10.mp4: 96
# SignSAF11.mp4: 48
# signML8.mp4: 90
# signEAF19.mp4: 55
# signANG8.mp4: 34
# signPB1.mp4: 73
# SignSAF30.mp4: 57
# signANG13.mp4: 35
# signEAF4.mp4: 39
# signML5.mp4: 83
# signANG14.mp4: 30
# signEAF30.mp4: 29
# signANG34.mp4: 29
# signADL10.mp4: 61
# signEAF5.mp4: 29
# signADL3.mp4: 100
# signADL5.mp4: 127
# signANG28.mp4: 25
# signADL24.mp4: 86
# signEAF22.mp4: 36
# SignSAF45.mp4: 48
# signANG16.mp4: 33
# signEAF27.mp4: 34
# signADL6.mp4: 119
# signADL14.mp4: 65
# SignSAF40.mp4: 46
# SignSAF36.mp4: 47
# SignSAF31.mp4: 49
# signANG33.mp4: 34
# signEAF13.mp4: 39
# signFr5.mp4: 102
# signEAF14.mp4: 48
# signADL13.mp4: 71
# signEAF28.mp4: 32
# signANG27.mp4: 30
# signANG31.mp4: 36
# signFr3.mp4: 69
# signANG10.mp4: 33
# signFr8.mp4: 79
# signFr4.mp4: 68
# signANG24.mp4: 29
# signADL15.mp4: 64
# signFr6.mp4: 70
# signANG38.mp4: 34
# signPB5.mp4: 85
# signANG19.mp4: 27
# SignSAF2.mp4: 71
# SignSAF41.mp4: 60
# signPB6.mp4: 72
# signANG9.mp4: 28
# signEAF26.mp4: 35
# signADL18.mp4: 62
# SignSAF25.mp4: 60
# signPB7.mp4: 54
# signANG36.mp4: 25
# signADL11.mp4: 51
# signPB4.mp4: 67
# signANG23.mp4: 28
# signANG32.mp4: 33
# SignSAF7.mp4: 48
# SignSAF29.mp4: 63
# signADL22.mp4: 66
# signEAF24.mp4: 31
# SignSAF46.mp4: 51
# signANG35.mp4: 36
# signANG20.mp4: 30
# SignSAF28.mp4: 60
# signADL9.mp4: 60
# signADL1.mp4: 97
# signPB12.mp4: 134
# SignSAF1.mp4: 67
# SignSAF13.mp4: 39
# signFr9.mp4: 109
# signEAF21.mp4: 39
# SignSAF35.mp4: 45
# SignSAF39.mp4: 45
# SignSAF9.mp4: 53
# signADL4.mp4: 97
# signANG6.mp4: 33
# SignSAF19.mp4: 55
# signEAF12.mp4: 32
# signANG11.mp4: 29
# SignSAF24.mp4: 53
# signEAF10.mp4: 30
# signPB11.mp4: 126
# signML1.mp4: 64
# signANG26.mp4: 34
# signPB2.mp4: 64
# signEAF17.mp4: 31
# signADL2.mp4: 142
# signEAF31.mp4: 28
# signANG4.mp4: 40
# SignSAF21.mp4: 50
# signADL8.mp4: 54
# signADL16.mp4: 86
# SignSAF27.mp4: 73
# SignSAF8.mp4: 44
# signEAF20.mp4: 31
# SignSAF4.mp4: 46
# signFr2.mp4: 57
# signANG7.mp4: 39
# signEAF3.mp4: 35
# signML4.mp4: 75
# signEAF23.mp4: 41
# SignSAF44.mp4: 59
# SignSAF22.mp4: 46
# SignSAF37.mp4: 40
# signADL23.mp4: 67
# SignSAF32.mp4: 54
# signEAF18.mp4: 37
# signANG17.mp4: 36
# signEAF25.mp4: 30
# SignSAF17.mp4: 46
# SignSAF10.mp4: 57
# SignSAF5.mp4: 53
# SignSAF18.mp4: 58
# SignSAF15.mp4: 48
# SignSAF43.mp4: 45
# SignSAF23.mp4: 89
# SignSAF16.mp4: 43
# signEAF9.mp4: 32
# signADL19.mp4: 58
# signANG22.mp4: 31
# signEAF1.mp4: 30
# signEAF15.mp4: 47
# signANG5.mp4: 42
# signANG2.mp4: 46
# signANG25.mp4: 31
# SignSAF12.mp4: 38
# signEAF7.mp4: 33
# signEAF29.mp4: 32
# signADL7.mp4: 133
# signEAF11.mp4: 31
# SignSAF14.mp4: 48
# signANG15.mp4: 37
# signADL17.mp4: 40
# signANG30.mp4: 31
# signPB9.mp4: 92
# signML10.mp4: 77
# signADL20.mp4: 80
# signML3.mp4: 59
# signADL12.mp4: 71
# signFr10.mp4: 68
# signANG39.mp4: 37
# SignSAF26.mp4: 56
# signANG12.mp4: 35
# SignSAF38.mp4: 48
# signML7.mp4: 75
# signANG37.mp4: 28
# SignSAF20.mp4: 46
# signPB3.mp4: 75
# signEAF16.mp4: 36
# SignSAF6.mp4: 43
#
# no:
# noADL2.mp4: 57
# noADL7.mp4: 54
# noPB1.mp4: 62
# noFr1.mp4: 96
# noADL3.mp4: 65
# noADL1.mp4: 56
# noML50.mp4: 45
# noFr2.mp4: 62
# noML53.mp4: 64
# noFr3.mp4: 83
# noML54.mp4: 60
# noML52.mp4: 62
# noADL8.mp4: 61
# noADL4.mp4: 49
# noADL5.mp4: 52
# noML51.mp4: 51
# noPB2.mp4: 76
# noADL6.mp4: 60
# noPB3.mp4: 45
# The mínimum number of frames is: 25 frames
# ...Done
